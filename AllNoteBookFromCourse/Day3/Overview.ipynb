# %% [markdown]
# ![ml_welcome.png](attachment:ml_welcome.png)

# %% [markdown]
# <p style="line-height:1.75;font-size:18px">
# In this part of the course we're going to learn about machine learning - what is it, how does it work and how do we use it.<br>
# <p style="line-height:1.75;font-size:18px">
# Most lessons adhere to a pattern of understanding the motivation, learning the theory, walk-through of an example together and finally doing an exercise in Python alone.
#
# <p style="line-height:1.75;font-size:18px">
# The lessons are interactive and will require your participation - don't be shy, we're all learning together.
#
# <p style="line-height:1.75;font-size:18px">
# There are no home assignments but we will have small exercises during the lessons and bigger exercises at the end of each day where you will have time to apply what you've learned and ask questions.
#
# <p style="line-height:1.75;font-size:18px">
# All of the lessons and exercises are in a notebook format - this is a tool data scientists usually use on a daily basis, might as well get acquainted with it.
#
# <p style="line-height:1.75;font-size:18px">
# Towards the middle of this chapter, you will receive an assignment that you will be graded on. You will have about 2 weeks to complete it and we will have two half-days dedicated to working on it and asking questions.
#
# <p style="line-height:1.75;font-size:18px">
# If you have any questions or issues, besides Whatsapp, you can email me at: gad.markovits@gmail.com. Please make sure to put <b><u>uatt</u></b> in the email subject.
#
# <p style="line-height:1.75;font-size:18px">
# Am I going too fast? Too slow? Is there some topic you feel we should review again? This course has been specifically tailored for you so it's the first time it's being taught in its entirety (and remotely on top of that...). Please send any and all feedback (good or bad) you might have as early as possible. Don't wait until the chapter/course ends - we can still adjust things and solve issues if we know about them.
#
# <p style="line-height:1.75;font-size:18px">
# There are a few prompts in the notebooks themselves that we will use throughout the chapter:

# %% [markdown]
# <div style="line-height:1.75;background:#3464a2;padding-left:20px;padding-top:5px;padding-bottom:5px;border-radius:5px 5px 0px 0px">
# <i class="fa fa-question" style="font-size:40px;color:#e6f1ff;"></i>
# </div>
# <div>
# <p style="line-height:1.75;font-size:16px;background:#e6f1ff;padding:20px;border-radius:0px 0px 5px 5px">
# This is a discussion prompt - it's meant to ask a question and create a discussion in class. Your participation in these discussions will help not only you but the rest of group as well.
# </p></div>

# %% [markdown]
# <div style="line-height:1.75;background:#f6e609;padding-left:20px;padding-top:5px;padding-bottom:5px;border-radius:5px 5px 0px 0px">
# <i class="fa fa-lightbulb-o" style="font-size: 50px;color:#ffffcc;"></i>
# </div>
# <div>
# <p style="line-height:1.75;font-size:16px;background:#ffffcc;padding:20px;border-radius:0px 0px 5px 5px">
# <span style="font-size:16px"><b>Information</b></span><br>
# This is an information prompt - it usually appears when there's more to be said about a topic but it's beyond the scope of our class. Usually this prompt will also have a link where you can read more about the topic if you're interested (highly encouraged)</p></div>

# %% [markdown]
# <div style="line-height:1.75;background:#990000;padding-left:20px;padding-top:5px;padding-bottom:5px;border-radius:5px 5px 0px 0px">
# <i class="fa fa-exclamation-triangle" style="font-size:40px;color:#ffb3b3;"></i>
# </div>
# <div>
# <p style="line-height:1.75;font-size:16px;background:#ffb3b3;padding:20px;border-radius:0px 0px 5px 5px">
# This is a warning prompt - it appears when there is an issue we should pay close attention to in order to avoid mistakes.
# </p></div>

# %% [markdown]
# <div style="line-height:1.75;background:#1e7b1e;padding-left:20px;padding-top:5px;padding-bottom:5px;border-radius:5px 5px 0px 0px">
# <i class="fa fa-pencil" style="font-size:40px;color:#c1f0c1;"></i>
# </div>
# <div>
# <p style="line-height:1.75;font-size:16px;background:#c1f0c1;padding:20px;border-radius:0px 0px 5px 5px">
# This is an exercise prompt - when it appears it means that we will take a few minutes to try and solve a problem by ourselves. During this time you can ask questions either in the class room or a private room if you need to show a specific issue. At the end of the exercise you might be asked to share your solution with the class.
# </div>
